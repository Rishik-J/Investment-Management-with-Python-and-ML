# %% [markdown]
# # Efficient Frontier
# The main types of portfolios that a mean-variance investor is interested in
#
# - EF represetns the portfolio of highest expected return for a given level of volatility
#
# - make up the edge of the risk-retun region when analysizing multiple portfolios

# %%
import pandas as pd
import numpy as np
import QFModule as qf
# %load_ext autoreload
# %autoreload 2

# %%
#Importing dataset containg montly returns of 30 different industry portfolios
ind = pd.read_csv('ind30_m_ew_rets.csv', 
                  header =0, index_col =0, parse_dates= True) / 100

ind.index = pd.to_datetime(ind.index, format = "%Y%m").to_period('M')
ind.columns = ind.columns.str.strip()
ind.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0086 -0.0536  0.0167  0.0231  0.2628  0.0245 -0.0068  0.0245
# 1926-08  0.0370  0.1925  0.0501  0.0253  0.2118 -0.0286  0.0479  0.0611
# 1926-09  0.0138  0.0563  0.0310  0.0413 -0.0204  0.0176 -0.0616  0.0080
# 1926-10 -0.0470 -0.0608 -0.0163 -0.0576  0.0833 -0.0298 -0.0112  0.0013
# 1926-11  0.0674  0.1129  0.0958  0.0028 -0.0598  0.0165  0.0085  0.0720
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0101  0.0044  ...  0.0131  0.0776  0.0313  0.0129 -0.0089 -0.2023
# 1926-08  0.0302  0.0431  ...  0.0108  0.0420  0.0120  0.0400  0.0513  0.0942
# 1926-09  0.0240 -0.0409  ...  0.0022 -0.0628 -0.0089 -0.0664 -0.0028  0.0032
# 1926-10 -0.0877  0.0192  ... -0.0099 -0.0410 -0.0588 -0.0490 -0.0233 -0.0621
# 1926-11  0.0534  0.0454  ...  0.0148 -0.0362  0.0165  0.0260  0.0042 -0.0026
#
#           Rtail   Meals     Fin   Other
# ...

# %%
covarianceMatrix = ind['1995':'2000'].cov()
covarianceMatrix.head()
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.001494  0.001181  0.001298  0.001595  0.001355  0.001463  0.001545
# Beer   0.001181  0.002601  0.001987  0.001670  0.001196  0.001474  0.001449
# Smoke  0.001298  0.001987  0.008750  0.001377  0.001481  0.001274  0.001629
# Games  0.001595  0.001670  0.001377  0.004362  0.002448  0.002556  0.002849
# Books  0.001355  0.001196  0.001481  0.002448  0.002273  0.001742  0.002087
#
#            Hlth     Chems     Txtls  ...     Telcm     Servs     BusEq  \
# Food   0.002312  0.001304  0.001143  ...  0.001917  0.002004  0.002355
# Beer   0.002127  0.001325  0.001060  ...  0.001558  0.001710  0.002108
# Smoke  0.002629  0.001430  0.001064  ...  0.001117  0.001651  0.002034
# Games  0.004398  0.002193  0.002040  ...  0.004905  0.004884  0.005525
# Books  0.002907  0.001724  0.001639  ...  0.003204  0.003292  0.003694
#
#           Paper     Trans     Whlsl     Rtail     Meals       Fin     Other
# ...

# %% [markdown]
# ## Covarience & Volatilatiy
# The portfolio volatility is a function of the covariances between each pair of assets, which in turn depends on the volatilities and correlations of the assets
#
#
# The Covariance Matrix is a symmetric matrix with variances along the diagonal and the product of the pairwise correlation and the individual volatililites (i.e. the covariance) on the off-diagonal entries

# %%
er = qf.annualize_returns(ind['1996':'2000'], 12)
cov = ind['1996':'2000'].cov()

# %%
def portfolio_return(weigths, returns):
    """
    Using weigths to get returns
    Transposes weights and matrix multies with returns
    """
    return weights.T @ returns

def portfolio_volatility(weights, covMatrix):
    """
    usign weights and covarience matrix to get volatilaty
    """
    return weights.T @ covMatrix @ weights
